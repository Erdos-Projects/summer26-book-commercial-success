# %% [markdown]
# > **Superseded exploratory notebook** — groundwork for secondary-dataset enrichment (publisher information using OpenLibrary API). Not part of the final modelling pipeline; see `EDA/book_success_merge.ipynb` and `methodology/design.md` for the canonical pipeline.

# %% [markdown]
# **Input:** `merged_books.csv` and OpenLibrary Books API
#
# **Output:** `publisher_cache.csv`, with columns `isbn13_lookup`, `publisher_or_imprint`, and `publisher_source`

# %% [markdown]
# ## 0. Install & Import

# %%
import pandas as pd
import requests
import time
import re
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# ## 1. Load Datasets
# **Thao_analysis**:
# - merged_books.csv -- embedding of nyt_hardcover_fiction_bestsellers into our baseline Goodbooks

# %%
df = pd.read_csv("data/merged_books.csv", dtype={"isbn13": str})

df.head()

print(df.shape)
display(df[["title", "authors", "isbn13", "genres"]].head(5))
# Out:
# (9417, 48)
#                                                title  \
# 0            The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2                            Twilight (Twilight, #1)
# 3                              To Kill a Mockingbird
# 4                             The Fault in Our Stars
#
#                              authors           isbn13  \
# 0                ['Suzanne Collins']  9780439023480.0
# 1  ['J.K. Rowling', 'Mary GrandPré']  9780439554930.0
# 2                ['Stephenie Meyer']  9780316015840.0
# 3                     ['Harper Lee']  9780061120080.0
# 4                     ['John Green']  9780525478810.0
#
#                                               genres
# 0  ['young-adult', 'fiction', 'fantasy', 'science...
# 1  ['fantasy', 'fiction', 'young-adult', 'classics']
# 2  ['young-adult', 'fantasy', 'romance', 'fiction...
# 3  ['classics', 'fiction', 'historical-fiction', ...
# 4  ['young-adult', 'romance', 'fiction', 'contemp...

# %% [markdown]
# ## 2. Update dataset
# Remove all the non-fiction books

# %%
def parse_genres(x):
    if pd.isna(x):
        return []
    
    # If already a list, return it
    if isinstance(x, list):
        return x
    
    x = str(x).strip()
    
    # Remove extra outer quotes if they exist
    if (x.startswith('"') and x.endswith('"')) or (x.startswith("'") and x.endswith("'")):
        x = x[1:-1]
    
    try:
        parsed = ast.literal_eval(x)
        if isinstance(parsed, list):
            return parsed
        else:
            return [parsed]
    except Exception:
        return [x]

def is_nonfiction_book(genres):
    genres = parse_genres(genres)
    
    genres_clean = [
        str(g).lower().strip()
        for g in genres
    ]
    
    return "nonfiction" in genres_clean

# %%
df["is_nonfiction"] = df["genres"].apply(is_nonfiction_book)

num_nonfiction = df["is_nonfiction"].sum()
total_books = len(df)
nonfiction_rate = num_nonfiction / total_books

print(f"Number of non-fiction books: {num_nonfiction}")
print(f"Total books: {total_books}")
print(f"Non-fiction rate: {nonfiction_rate:.2%}")
# Out:
# Number of non-fiction books: 0
# Total books: 9417
# Non-fiction rate: 0.00%

# %% [markdown]
# ---
# ## 3. Enrich dataset
#
# **Goals:**
# - Use Open Library,GoogleBooks API to add 'publisher_or_imprint' column

# %%
# -- 2a. Setup & Clean ISBN13 ---------------
ISBN_COL = "isbn13"
CACHE_PATH = Path("publisher_cache.csv")

USER_AGENT = "BookSuccessBootcampProject/1.0 (ron.yang228@gmail.com)"

# Optional. Leave as None unless you have a Google Books API key.
GOOGLE_BOOKS_API_KEY = None

def clean_isbn13(x):
    if pd.isna(x):
        return None
    
    x = str(x).strip()
    x = re.sub(r"\.0$", "", x)
    x = re.sub(r"[^0-9]", "", x)
    
    if len(x) == 13:
        return x
    
    return None 

df["isbn13_lookup"] = df[ISBN_COL].apply(clean_isbn13)

df[["title", "isbn13", "isbn13_lookup"]].head(20)
# Out:
#                                                 title           isbn13  \
# 0             The Hunger Games (The Hunger Games, #1)  9780439023480.0
# 1   Harry Potter and the Sorcerer's Stone (Harry P...  9780439554930.0
# 2                             Twilight (Twilight, #1)  9780316015840.0
# 3                               To Kill a Mockingbird  9780061120080.0
# 4                              The Fault in Our Stars  9780525478810.0
# 5                                          The Hobbit  9780618260300.0
# 6                              The Catcher in the Rye  9780316769170.0
# 7               Angels & Demons  (Robert Langdon, #1)  9781416524790.0
# 8                                     The Kite Runner  9781594480000.0
# 9                           Divergent (Divergent, #1)  9780062024040.0
# 10                          The Diary of a Young Girl  9780553296980.0
# 11   The Girl with the Dragon Tattoo (Millennium, #1)  9780307269750.0
# 12               Catching Fire (The Hunger Games, #2)  9780439023500.0
# 13  Harry Potter and the Prisoner of Azkaban (Harr...  9780439655480.0
# 14                  Mockingjay (The Hunger Games, #3)  9780439023510.0
# 15  Harry Potter and the Order of the Phoenix (Har...  9780439358070.0
# 16                                   The Lovely Bones  9780316166680.0
# 17  Harry Potter and the Chamber of Secrets (Harry...  9780439064870.0
# 18  Harry Potter and the Goblet of Fire (Harry Pot...  9780439139600.0
# 19  Harry Potter and the Deathly Hallows (Harry Po...  9780545010220.0
#
#     isbn13_lookup
# 0   9780439023480
# 1   9780439554930
# 2   9780316015840
# 3   9780061120080
# 4   9780525478810
# 5   9780618260300
# 6   9780316769170
# 7   9781416524790
# 8   9781594480000
# 9   9780062024040
# 10  9780553296980
# 11  9780307269750
# 12  9780439023500
# 13  9780439655480
# 14  9780439023510
# 15  9780439358070
# 16  9780316166680
# 17  9780439064870
# 18  9780439139600
# 19  9780545010220

# %%
# -- 2b. Open Library Lookup ---------------

def get_openlibrary_publisher(isbn13):
    if isbn13 is None:
        return None
    
    url = f"https://openlibrary.org/isbn/{isbn13}.json"
    headers = {"User-Agent": USER_AGENT}
    
    try:
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return None
        
        data = r.json()
        publishers = data.get("publishers", [])
        
        if isinstance(publishers, list) and len(publishers) > 0:
            return publishers[0]
        
        return None
    
    except Exception:
        return None

# %%
# -- 2c. GoogleBook Lookup ---------------
def get_google_books_publisher(isbn13):
    if isbn13 is None:
        return None
    
    url = "https://www.googleapis.com/books/v1/volumes"
    params = {
        "q": f"isbn:{isbn13}",
        "fields": "items(volumeInfo/publisher)"
    }
    
    if GOOGLE_BOOKS_API_KEY is not None:
        params["key"] = GOOGLE_BOOKS_API_KEY
    
    try:
        r = requests.get(url, params=params, timeout=10)
        
        if r.status_code != 200:
            return None
        
        data = r.json()
        items = data.get("items", [])
        
        if len(items) == 0:
            return None
        
        return items[0].get("volumeInfo", {}).get("publisher", None)
    
    except Exception:
        return None

# %%
# -- 2d. Combined Lookup ---------------
def get_publisher_or_imprint(isbn13, sleep_time=0.25):
    publisher = get_openlibrary_publisher(isbn13)
    
    if publisher is not None:
        time.sleep(sleep_time)
        return publisher, "openlibrary"
    
    time.sleep(sleep_time)
    
    publisher = get_google_books_publisher(isbn13)
    
    if publisher is not None:
        time.sleep(sleep_time)
        return publisher, "google_books"
    
    time.sleep(sleep_time)
    return None, "missing"

# %%
# -- 2e. Build Cache ---------------
def build_publisher_cache(df, isbn_col="isbn13_lookup", cache_path=CACHE_PATH):
    unique_isbns = sorted(df[isbn_col].dropna().unique())
    
    if cache_path.exists():
        cache = pd.read_csv(cache_path, dtype={"isbn13_lookup": str})
    else:
        cache = pd.DataFrame(
            columns=["isbn13_lookup", "publisher_or_imprint", "publisher_source"]
        )
    
    already_done = set(cache["isbn13_lookup"].dropna().astype(str))
    missing_isbns = [isbn for isbn in unique_isbns if isbn not in already_done]
    
    print(f"Total unique ISBNs: {len(unique_isbns)}")
    print(f"Already cached: {len(already_done)}")
    print(f"Need to query: {len(missing_isbns)}")
    
    new_rows = []
    
    for isbn in tqdm(missing_isbns):
        publisher, source = get_publisher_or_imprint(isbn)
        
        new_rows.append({
            "isbn13_lookup": isbn,
            "publisher_or_imprint": publisher,
            "publisher_source": source
        })
        
        if len(new_rows) % 100 == 0:
            cache = pd.concat([cache, pd.DataFrame(new_rows)], ignore_index=True)
            cache.to_csv(cache_path, index=False)
            new_rows = []
    
    if len(new_rows) > 0:
        cache = pd.concat([cache, pd.DataFrame(new_rows)], ignore_index=True)
        cache.to_csv(cache_path, index=False)
    
    return cache

# %%
# -- 2f. Add publisher column to the dataset ---------------
publisher_cache = build_publisher_cache(df)

df = df.merge(
    publisher_cache,
    on="isbn13_lookup",
    how="left"
)

df["publisher_or_imprint"] = df["publisher_or_imprint"].fillna("Unknown")
df["publisher_source"] = df["publisher_source"].fillna("missing")

# %%
print(df.shape)
display(df[["title", "isbn13_lookup", "publisher_or_imprint", "publisher_source"]].head(20))
# Out:
# (9417, 51)
#                                                 title  isbn13_lookup  \
# 0             The Hunger Games (The Hunger Games, #1)  9780439023480
# 1   Harry Potter and the Sorcerer's Stone (Harry P...  9780439554930
# 2                             Twilight (Twilight, #1)  9780316015840
# 3                               To Kill a Mockingbird  9780061120080
# 4                              The Fault in Our Stars  9780525478810
# 5                                          The Hobbit  9780618260300
# 6                              The Catcher in the Rye  9780316769170
# 7               Angels & Demons  (Robert Langdon, #1)  9781416524790
# 8                                     The Kite Runner  9781594480000
# 9                           Divergent (Divergent, #1)  9780062024040
# 10                          The Diary of a Young Girl  9780553296980
# 11   The Girl with the Dragon Tattoo (Millennium, #1)  9780307269750
# 12               Catching Fire (The Hunger Games, #2)  9780439023500
# 13  Harry Potter and the Prisoner of Azkaban (Harr...  9780439655480
# 14                  Mockingjay (The Hunger Games, #3)  9780439023510
# 15  Harry Potter and the Order of the Phoenix (Har...  9780439358070
# 16                                   The Lovely Bones  9780316166680
# 17  Harry Potter and the Chamber of Secrets (Harry...  9780439064870
# 18  Harry Potter and the Goblet of Fire (Harry Pot...  9780439139600
# 19  Harry Potter and the Deathly Hallows (Harry Po...  9780545010220
#
#       publisher_or_imprint publisher_source
# 0                  Unknown          missing
# 1   Arthur A. Levine Books      openlibrary
# 2                  Unknown          missing
# 3                  Unknown          missing
# 4                  Unknown          missing
# 5         Houghton Mifflin      openlibrary
# 6                  Unknown          missing
# 7                  Unknown          missing
# 8                  Unknown          missing
# 9                  Unknown          missing
# 10                 Unknown          missing
# 11                 Unknown          missing
# 12                 Unknown          missing
# 13                 Unknown          missing
# 14                 Unknown          missing
# 15                 Unknown          missing
# 16                 Unknown          missing
# 17                 Unknown          missing
# 18                 Unknown          missing
# 19                 Unknown          missing

# %% [markdown]
# ## Publisher cache coverage visualization
#
# This section reads the saved cache only; it does not rerun any API lookups or enrichment code. Counts represent unique ISBNs in `publisher_cache.csv`.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

cache_candidates = [
    Path("../data/publisher_cache.csv"),                # kernel started in notebooks/
    Path("data/publisher_cache.csv"),                   # kernel started in project root
    Path("Erdos2026-data-science/data/publisher_cache.csv"),  # kernel started in Erdos/
]
cache_path = next((path for path in cache_candidates if path.exists()), None)
if cache_path is None:
    raise FileNotFoundError(f"publisher_cache.csv not found from working directory: {Path.cwd()}")

publisher_cache_plot = pd.read_csv(cache_path)
source_counts = publisher_cache_plot["publisher_source"].value_counts()
found = source_counts.get("openlibrary", 0)
missing = source_counts.get("missing", 0)
total = found + missing
coverage = found / total

fig, ax = plt.subplots(figsize=(10, 2.8))
ax.barh(0, found, color="#87CEEB", alpha=0.9, height=0.55, label="Found via Open Library")
ax.barh(0, missing, left=found, color="#F4A6A6", alpha=0.9, height=0.55, label="Missing")

ax.text(found / 2, 0, f"Open Library\n{found:,} ({coverage:.1%})",
        ha="center", va="center", color="#174A5B", fontweight="bold")
ax.text(found + missing / 2, 0, f"Missing\n{missing:,} ({missing / total:.1%})",
        ha="center", va="center", color="#3D3D3D", fontweight="bold")

ax.set_xlim(0, total)
ax.set_yticks([])
ax.set_xlabel(f"Unique ISBNs in publisher cache (n = {total:,})")
ax.set_title(f"Publisher Cache Coverage: {coverage:.1%}", loc="left", fontweight="bold")
ax.spines[["top", "right", "left"]].set_visible(False)
ax.legend(loc="upper center", bbox_to_anchor=(0.5, -0.28), ncol=2, frameon=False)
plt.tight_layout()

# figure_dir = cache_path.resolve().parent.parent / "figures"
# figure_dir.mkdir(parents=True, exist_ok=True)
# figure_path = figure_dir / "publisher_cache_coverage.png"
# fig.savefig(figure_path, dpi=300, bbox_inches="tight", facecolor="white")
# print(f"Saved plot to: {figure_path}")

plt.show()

# %% [markdown]
# **Conclusion:** Publisher coverage from OpenLibrary was very low: only 866 out of 9,417 books, or 9.20%, received publisher/imprint information, while 8,551 books remained missing. Because of this low coverage, publisher/imprint metadata is too incomplete to use as a reliable baseline feature in the main model. We keep `publisher_cache.csv` as an exploratory side output, but we do not include publisher features in the main feature engineering pipeline.

# %% [markdown]
# ## 0. Install & Import

# %%
import pandas as pd
import requests
import time
import re
from pathlib import Path
from tqdm import tqdm

# %% [markdown]
# ## 1. Load Datasets
# **Thao_analysis**:
# - merged_books.csv -- embedding of nyt_hardcover_fiction_bestsellers into our baseline Goodbooks

# %%
df = pd.read_csv("data/merged_books.csv", dtype={"isbn13": str})

df.head()

print(df.shape)
display(df[["title", "authors", "isbn13", "genres"]].head(5))
# Out:
# (9417, 48)
#                                                title  \
# 0            The Hunger Games (The Hunger Games, #1)
# 1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2                            Twilight (Twilight, #1)
# 3                              To Kill a Mockingbird
# 4                             The Fault in Our Stars
#
#                              authors           isbn13  \
# 0                ['Suzanne Collins']  9780439023480.0
# 1  ['J.K. Rowling', 'Mary GrandPré']  9780439554930.0
# 2                ['Stephenie Meyer']  9780316015840.0
# 3                     ['Harper Lee']  9780061120080.0
# 4                     ['John Green']  9780525478810.0
#
#                                               genres
# 0  ['young-adult', 'fiction', 'fantasy', 'science...
# 1  ['fantasy', 'fiction', 'young-adult', 'classics']
# 2  ['young-adult', 'fantasy', 'romance', 'fiction...
# 3  ['classics', 'fiction', 'historical-fiction', ...
# 4  ['young-adult', 'romance', 'fiction', 'contemp...

# %% [markdown]
# ## 2. Update dataset
# Remove all the non-fiction books

# %%
def parse_genres(x):
    if pd.isna(x):
        return []
    
    # If already a list, return it
    if isinstance(x, list):
        return x
    
    x = str(x).strip()
    
    # Remove extra outer quotes if they exist
    if (x.startswith('"') and x.endswith('"')) or (x.startswith("'") and x.endswith("'")):
        x = x[1:-1]
    
    try:
        parsed = ast.literal_eval(x)
        if isinstance(parsed, list):
            return parsed
        else:
            return [parsed]
    except Exception:
        return [x]

def is_nonfiction_book(genres):
    genres = parse_genres(genres)
    
    genres_clean = [
        str(g).lower().strip()
        for g in genres
    ]
    
    return "nonfiction" in genres_clean

# %%
df["is_nonfiction"] = df["genres"].apply(is_nonfiction_book)

num_nonfiction = df["is_nonfiction"].sum()
total_books = len(df)
nonfiction_rate = num_nonfiction / total_books

print(f"Number of non-fiction books: {num_nonfiction}")
print(f"Total books: {total_books}")
print(f"Non-fiction rate: {nonfiction_rate:.2%}")
# Out:
# Number of non-fiction books: 0
# Total books: 9417
# Non-fiction rate: 0.00%

# %% [markdown]
# ---
# ## 3. Enrich dataset
#
# **Goals:**
# - Use Open Library,GoogleBooks API to add 'publisher_or_imprint' column

# %%
# -- 2a. Setup & Clean ISBN13 ---------------
ISBN_COL = "isbn13"
CACHE_PATH = Path("publisher_cache.csv")

USER_AGENT = "BookSuccessBootcampProject/1.0 (ron.yang228@gmail.com)"

# Optional. Leave as None unless you have a Google Books API key.
GOOGLE_BOOKS_API_KEY = None

def clean_isbn13(x):
    if pd.isna(x):
        return None
    
    x = str(x).strip()
    x = re.sub(r"\.0$", "", x)
    x = re.sub(r"[^0-9]", "", x)
    
    if len(x) == 13:
        return x
    
    return None 

df["isbn13_lookup"] = df[ISBN_COL].apply(clean_isbn13)

df[["title", "isbn13", "isbn13_lookup"]].head(20)
# Out:
#                                                 title           isbn13  \
# 0             The Hunger Games (The Hunger Games, #1)  9780439023480.0
# 1   Harry Potter and the Sorcerer's Stone (Harry P...  9780439554930.0
# 2                             Twilight (Twilight, #1)  9780316015840.0
# 3                               To Kill a Mockingbird  9780061120080.0
# 4                              The Fault in Our Stars  9780525478810.0
# 5                                          The Hobbit  9780618260300.0
# 6                              The Catcher in the Rye  9780316769170.0
# 7               Angels & Demons  (Robert Langdon, #1)  9781416524790.0
# 8                                     The Kite Runner  9781594480000.0
# 9                           Divergent (Divergent, #1)  9780062024040.0
# 10                          The Diary of a Young Girl  9780553296980.0
# 11   The Girl with the Dragon Tattoo (Millennium, #1)  9780307269750.0
# 12               Catching Fire (The Hunger Games, #2)  9780439023500.0
# 13  Harry Potter and the Prisoner of Azkaban (Harr...  9780439655480.0
# 14                  Mockingjay (The Hunger Games, #3)  9780439023510.0
# 15  Harry Potter and the Order of the Phoenix (Har...  9780439358070.0
# 16                                   The Lovely Bones  9780316166680.0
# 17  Harry Potter and the Chamber of Secrets (Harry...  9780439064870.0
# 18  Harry Potter and the Goblet of Fire (Harry Pot...  9780439139600.0
# 19  Harry Potter and the Deathly Hallows (Harry Po...  9780545010220.0
#
#     isbn13_lookup
# 0   9780439023480
# 1   9780439554930
# 2   9780316015840
# 3   9780061120080
# 4   9780525478810
# 5   9780618260300
# 6   9780316769170
# 7   9781416524790
# 8   9781594480000
# 9   9780062024040
# 10  9780553296980
# 11  9780307269750
# 12  9780439023500
# 13  9780439655480
# 14  9780439023510
# 15  9780439358070
# 16  9780316166680
# 17  9780439064870
# 18  9780439139600
# 19  9780545010220

# %%
# -- 2b. Open Library Lookup ---------------

def get_openlibrary_publisher(isbn13):
    if isbn13 is None:
        return None
    
    url = f"https://openlibrary.org/isbn/{isbn13}.json"
    headers = {"User-Agent": USER_AGENT}
    
    try:
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return None
        
        data = r.json()
        publishers = data.get("publishers", [])
        
        if isinstance(publishers, list) and len(publishers) > 0:
            return publishers[0]
        
        return None
    
    except Exception:
        return None

# %%
# -- 2c. GoogleBook Lookup ---------------
def get_google_books_publisher(isbn13):
    if isbn13 is None:
        return None
    
    url = "https://www.googleapis.com/books/v1/volumes"
    params = {
        "q": f"isbn:{isbn13}",
        "fields": "items(volumeInfo/publisher)"
    }
    
    if GOOGLE_BOOKS_API_KEY is not None:
        params["key"] = GOOGLE_BOOKS_API_KEY
    
    try:
        r = requests.get(url, params=params, timeout=10)
        
        if r.status_code != 200:
            return None
        
        data = r.json()
        items = data.get("items", [])
        
        if len(items) == 0:
            return None
        
        return items[0].get("volumeInfo", {}).get("publisher", None)
    
    except Exception:
        return None

# %%
# -- 2d. Combined Lookup ---------------
def get_publisher_or_imprint(isbn13, sleep_time=0.25):
    publisher = get_openlibrary_publisher(isbn13)
    
    if publisher is not None:
        time.sleep(sleep_time)
        return publisher, "openlibrary"
    
    time.sleep(sleep_time)
    
    publisher = get_google_books_publisher(isbn13)
    
    if publisher is not None:
        time.sleep(sleep_time)
        return publisher, "google_books"
    
    time.sleep(sleep_time)
    return None, "missing"

# %%
# -- 2e. Build Cache ---------------
def build_publisher_cache(df, isbn_col="isbn13_lookup", cache_path=CACHE_PATH):
    unique_isbns = sorted(df[isbn_col].dropna().unique())
    
    if cache_path.exists():
        cache = pd.read_csv(cache_path, dtype={"isbn13_lookup": str})
    else:
        cache = pd.DataFrame(
            columns=["isbn13_lookup", "publisher_or_imprint", "publisher_source"]
        )
    
    already_done = set(cache["isbn13_lookup"].dropna().astype(str))
    missing_isbns = [isbn for isbn in unique_isbns if isbn not in already_done]
    
    print(f"Total unique ISBNs: {len(unique_isbns)}")
    print(f"Already cached: {len(already_done)}")
    print(f"Need to query: {len(missing_isbns)}")
    
    new_rows = []
    
    for isbn in tqdm(missing_isbns):
        publisher, source = get_publisher_or_imprint(isbn)
        
        new_rows.append({
            "isbn13_lookup": isbn,
            "publisher_or_imprint": publisher,
            "publisher_source": source
        })
        
        if len(new_rows) % 100 == 0:
            cache = pd.concat([cache, pd.DataFrame(new_rows)], ignore_index=True)
            cache.to_csv(cache_path, index=False)
            new_rows = []
    
    if len(new_rows) > 0:
        cache = pd.concat([cache, pd.DataFrame(new_rows)], ignore_index=True)
        cache.to_csv(cache_path, index=False)
    
    return cache

# %%
# -- 2f. Add publisher column to the dataset ---------------
publisher_cache = build_publisher_cache(df)

df = df.merge(
    publisher_cache,
    on="isbn13_lookup",
    how="left"
)

df["publisher_or_imprint"] = df["publisher_or_imprint"].fillna("Unknown")
df["publisher_source"] = df["publisher_source"].fillna("missing")

# %%
print(df.shape)
display(df[["title", "isbn13_lookup", "publisher_or_imprint", "publisher_source"]].head(20))
# Out:
# (9417, 51)
#                                                 title  isbn13_lookup  \
# 0             The Hunger Games (The Hunger Games, #1)  9780439023480
# 1   Harry Potter and the Sorcerer's Stone (Harry P...  9780439554930
# 2                             Twilight (Twilight, #1)  9780316015840
# 3                               To Kill a Mockingbird  9780061120080
# 4                              The Fault in Our Stars  9780525478810
# 5                                          The Hobbit  9780618260300
# 6                              The Catcher in the Rye  9780316769170
# 7               Angels & Demons  (Robert Langdon, #1)  9781416524790
# 8                                     The Kite Runner  9781594480000
# 9                           Divergent (Divergent, #1)  9780062024040
# 10                          The Diary of a Young Girl  9780553296980
# 11   The Girl with the Dragon Tattoo (Millennium, #1)  9780307269750
# 12               Catching Fire (The Hunger Games, #2)  9780439023500
# 13  Harry Potter and the Prisoner of Azkaban (Harr...  9780439655480
# 14                  Mockingjay (The Hunger Games, #3)  9780439023510
# 15  Harry Potter and the Order of the Phoenix (Har...  9780439358070
# 16                                   The Lovely Bones  9780316166680
# 17  Harry Potter and the Chamber of Secrets (Harry...  9780439064870
# 18  Harry Potter and the Goblet of Fire (Harry Pot...  9780439139600
# 19  Harry Potter and the Deathly Hallows (Harry Po...  9780545010220
#
#       publisher_or_imprint publisher_source
# 0                  Unknown          missing
# 1   Arthur A. Levine Books      openlibrary
# 2                  Unknown          missing
# 3                  Unknown          missing
# 4                  Unknown          missing
# 5         Houghton Mifflin      openlibrary
# 6                  Unknown          missing
# 7                  Unknown          missing
# 8                  Unknown          missing
# 9                  Unknown          missing
# 10                 Unknown          missing
# 11                 Unknown          missing
# 12                 Unknown          missing
# 13                 Unknown          missing
# 14                 Unknown          missing
# 15                 Unknown          missing
# 16                 Unknown          missing
# 17                 Unknown          missing
# 18                 Unknown          missing
# 19                 Unknown          missing

# %% [markdown]
# **Conclusion:** Publisher coverage from OpenLibrary was very low: only 866 out of 9,417 books, or 9.20%, received publisher/imprint information, while 8,551 books remained missing. Because of this low coverage, publisher/imprint metadata is too incomplete to use as a reliable baseline feature in the main model. We keep `publisher_cache.csv` as an exploratory side output, but we do not include publisher features in the main feature engineering pipeline.
